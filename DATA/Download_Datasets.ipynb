# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from huggingface_hub import snapshot_download
msrvtt_dir = '/content/drive/Shareddrives/DATA 298A/DATA/MSRVTT'
os.makedirs(msrvtt_dir, exist_ok=True)
snapshot_download(repo_id="VLM2Vec/MSR-VTT", repo_type="dataset", local_dir=msrvtt_dir, local_dir_use_symlinks=False)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:206: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `snapshot_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Fetching ... files: 0it [00:00, ?it/s]
# '/content/drive/Shareddrives/DATA 298A/DATA/MSRVTT'

# %%
import os
from huggingface_hub import snapshot_download

msvd_dir = '/content/drive/Shareddrives/DATA 298A/DATA/MSVD'
os.makedirs(msvd_dir, exist_ok=True)

snapshot_download(repo_id="VLM2Vec/MSVD", repo_type="dataset", local_dir=msvd_dir, local_dir_use_symlinks=False)
print("MSVD Download Process Finished!")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:206: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `snapshot_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# ...

# %%
# !pip install fiftyone
import fiftyone.zoo as foz
import fiftyone.core.config as fouc
import os

activitynet_dir = '/content/drive/Shareddrives/DATA 298A/DATA/ActivityNet'
os.makedirs(activitynet_dir, exist_ok=True)

fouc.set_config_settings(dataset_zoo_dir=activitynet_dir)

dataset = foz.load_zoo_dataset(
    "activitynet-200",
    dataset_dir=activitynet_dir,
)
print("ActivityNet Download Process Finished!")
